# %%
import numpy as np
from scipy.integrate import odeint
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import matplotlib.pyplot as plt
import matplotlib
from tqdm import tqdm
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 1.1 Simulation

# %%
def pendulum_rhs(y, t, alpha, mu):
    z, dz = y
    return [dz, -mu * np.sin(z) - alpha * np.abs(dz)*dz]

# %%
def simulate_pendulum(num, dt, z0, dz0, alpha, mu):
    t = np.linspace(0, num*dt, num)
    return odeint(pendulum_rhs, [z0, dz0], t, args=(alpha, mu)), np.array([t])

# %%
def generate_phase_portrait_grid(num, dt, alpha, mu, n):
    z = np.linspace(-1, 1, n)
    dz = np.linspace(-1, 1, n)
    fig, axs = plt.subplots(n, n)
    plt.suptitle(fr"Phase portait with parameters: t: {num*dt}s, ic $\in [-1, 1]^2$ $\alpha$: {alpha}, $\mu$: {mu}")
    for i in range(n):
        for j in range(n):
            z0 = z[i]
            dz0 = dz[j]
            z, dz = simulate_pendulum(num, dt, z0, dz0, alpha, mu)[0].T
            axs[i,j].plot(z, dz)
    fig.text(0.5, 0.01, 'z', ha='center')
    fig.text(0.01, 0.5, 'dz', va='center', rotation='vertical')
    
    plt.tight_layout()

# %%
generate_phase_portrait_grid(200, 0.1,0, 1, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 0.5, 1, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 1, 1, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 2, 1, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 0.1, 0, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 0.1, 1, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 0.1, 2, 3)

# %%
generate_phase_portrait_grid(200, 0.1, 0.1, 3, 3)

# %% [markdown]
# # 1.2

# %%
class PINN(nn.Module):
    def __init__(self, input_size, output_size, number_of_layers, layer_size, activation_function, rhs):
        super().__init__()
        self.layers = [nn.Linear(input_size, layer_size), activation_function()]
        
        for n in range(number_of_layers):
            self.layers.append(nn.Linear(layer_size, layer_size))
            self.layers.append(activation_function())
        
        self.layers.append(nn.Linear(layer_size, output_size))
        
        self.layers = nn.Sequential(*self.layers)
        self.rhs = rhs
        self.criterion = nn.MSELoss()
        
        self.lambda_ode = 1
        self.lambda_data = 1
    
    def forward(self, T):
        T = T.reshape(-1, 1)
        return torch.sin(self.layers(T))

    
    def loss_ODE(self, T):
        T.requires_grad = True
        T, _ = torch.sort(T)
        x = self.forward(T)
        dx = torch.autograd.grad(outputs=x, inputs=T, grad_outputs=torch.ones_like(x), create_graph=True)[0]
        ddx = torch.autograd.grad(outputs=dx, inputs=T, grad_outputs=torch.ones_like(dx), create_graph=True)[0]
        return self.criterion(torch.stack([dx, ddx]), self.rhs(x, _))
    
    def loss_data(self, X0, T0):
        return self.criterion(self.forward(T0), X0)
    
    def total_loss(self, T, CPs):
        X_ic = CPs[:, 1:] 
        T_ic = CPs[:, 0]
        # Compute losses
        loss_ODE = self.loss_ODE(T_ic)
        loss_data = self.loss_data(X_ic, T_ic)
        
        #return self.lambda_data * loss_data + self.lambda_ode * loss_ODE
        return self.lambda_ode * loss_ODE  + self.lambda_data * loss_data, torch.autograd.grad(loss_data, self.parameters(), retain_graph=True)[0], torch.autograd.grad(loss_ODE, self.parameters(), retain_graph=True)[0]

# %%
def train_pinn(model, t, train_data, num_cps, num_epochs, split_size, lr=0.001):
    #writer = SummaryWriter()
    data = np.hstack((t.T, train_data))
    
    X = torch.FloatTensor(data)
    dataset = TensorDataset(X)
    data_loader = DataLoader(dataset, batch_size=split_size, shuffle=False)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    CPs = X[torch.randint(len(X), (num_cps,))]
    print(CPs.shape)
    loss_list=[]
    for epoch in range(num_epochs):
        k = 0
        weights = [np.exp(0) for i in range(len(data_loader))]
        total_loss = 0
        for data in data_loader:
            input_times = data[0][:, 0]
            input_data = data[0][:, 1:]        
            loss, grad_data, grad_ode = model.total_loss(input_times, CPs)
           # writer.add_scalar(f'RAW_LOSS/{k}',loss, epoch)
            loss = weights[k] * loss
            total_loss += loss

        
            if epoch % 1000 == 999:
                weights[k] = torch.exp(-total_loss + loss)
                #writer.add_scalar(f'Weights/{k}', weights[k], epoch)
                #writer.add_scalar(f'Cum Loss/{k}',-total_loss + loss, epoch)

       #     writer.add_scalar(f'L/ODE', model.lambda_ode, k)
       #     writer.add_scalar(f'L/data',model.lambda_data, k)
       #     
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            k += 1
                    
        if epoch % 1000 == 999:
            grad = torch.norm(grad_data) + torch.norm(grad_ode)
            model.lambda_ode = 0.9 * model.lambda_ode + 0.1 * (grad / torch.norm(grad_ode))
            model.lambda_data = 0.9*model.lambda_data + 0.1 * (grad / torch.norm(grad_data))


        loss_list.append(loss.item())

    return loss_list, CPs

# %%
alpha = 0.1
mu = 1
data_train, t = simulate_pendulum(400, 0.1, 0, 0.9, alpha, mu)

# %%
model = PINN(1, 2, 3,64, nn.Tanh, lambda y, t: torch.FloatTensor(pendulum_rhs(y.detach().numpy().T, t, alpha, mu)))

# %%
loss_list, CPs = train_pinn(model, t, data_train,400, 1500, 64)
# Out:
# torch.Size([400, 3])
# /tmp/ipykernel_4296/3147419723.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /croot/pytorch_1686931851744/work/torch/csrc/utils/tensor_new.cpp:245.)
#   model = PINN(1, 2, 3,64, nn.Tanh, lambda y, t: torch.FloatTensor(pendulum_rhs(y.detach().numpy().T, t, alpha, mu)))

# %%
plt.plot(loss_list)

# %%
def create_plot(t, model, data_train):
    T = torch.FloatTensor(t)
    X = model.forward(T)
    X = X.detach().numpy()
    plt.plot(t.reshape(-1, 1), X[:, 0].reshape(-1, 1), label="Prediction z")
    #plt.plot(t.reshape(-1, 1), X[:, 1].reshape(-1, 1), label="Prediction dz")
    plt.scatter(CPs[:, 0],CPs[:, 1], marker="^", label="Colocation Points z")
    #plt.scatter(CPs[:, 0],CPs[:, 2], marker="x", label="Colocation Points dz")
    plt.figure()
    plt.plot(T.detach().numpy()[0, :], data_train[:, 0], label="True z")
    #plt.plot(T.detach().numpy()[0, :], data_train[:, 1], label="True dz")
    plt.legend()

# %%
create_plot(t, model, data_train)

# %%
model = PINN(1, 2, 3,256, nn.Tanh, lambda y, t: torch.FloatTensor(pendulum_rhs(y.detach().numpy().T, t, alpha, mu)))

# %%
loss_list, CPs = train_pinn(model, t, data_train ,1, 1000, 64)
# Out:
# torch.Size([1, 3])

# %%
plt.plot(loss_list)

# %%
create_plot(t, model, data_train)

# %% [markdown]
# ## 20 Positions given

# %%
model = PINN(1, 2, 3,256, nn.Tanh, lambda y, t: torch.FloatTensor(pendulum_rhs(y.detach().numpy().T, t, alpha, mu)))

# %%
loss_list, CPs = train_pinn(model, t, data_train,20, 1000, 64)
# Out:
# torch.Size([20, 3])

# %%
plt.plot(loss_list)

# %%
create_plot(t, model, data_train)

# %%
model = PINN(1, 2, 3,256, nn.Tanh, lambda y, t: torch.FloatTensor(pendulum_rhs(y.detach().numpy().T, t, alpha, mu)))
noisy_data_train = data_train + np.random.normal(0,0.1, data_train.shape)
noisy_t = t + np.random.normal(0,0.1, t.shape) + t

# %%
loss_list, CPs = train_pinn(model, t, noisy_data_train,20, 1000, 64)
# Out:
# torch.Size([20, 3])

# %%
plt.plot(loss_list)

# %%
create_plot(t, model, noisy_data_train)
